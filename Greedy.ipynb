# %% [markdown]
# ## Greedy
#
# ```
# - 현재 상황에서 지금 당장 좋은 것만 고르는 방법
# - 기준에 따라 좋은 것을 선택하는 알고리즘이므로, '가장 큰 순서대로', '가장 작은 순서대로'와 같은 기준을 알게 모르게 제시해준다.
# - 대체로 이 기준은 정렬 알고리즘을 사용했을 때 만족시킬 수 있으므로 그리디 알고리즘 문제는 자주 정렬 알고리즘과 짝을 이뤄 출제된다.
# ```

# %%
#@title 예제3-1 거스름돈

# 문제 내용 생략
# 예시) N = 1260 일때 500원 2개, 100원 2개, 50원 1개, 10원 1개

# 방향
# // 몫 % 나머지 사용
# 각 화폐별로 나누고 몫과 나머지를 구하고 남은 돈 업데이트하는 식으로 풀이

# 코드
n = 1260
count = 0

# 큰 단위의 화폐부터 차례대로 확인
coin_types = [500, 100, 50, 10]

for coin in coin_types:
    count += n // coin # 해당 화폐로 거슬러 줄 수 있는 동전 개수
    n %= coin

print(count)
# Out:
# 6

# %%
# 각 동전의 개수 출력
n = int(input())
count = 0

# 동전 개수 변수 추가
cnt_500 = 0
cnt_100 = 0
cnt_50 = 0
cnt_10 = 0

# 큰 단위의 화폐부터 차례대로 확인
coin_types = [500, 100, 50, 10]

for coin in coin_types:
    if n // coin > 0:  # 해당 화폐로 거슬러 줄 수 있는 동전이 있을 때
        coin_count = n // coin  # 해당 화폐로 거슬러 줄 수 있는 동전 개수
        count += coin_count  # 동전 개수 총합에 더하기
        n %= coin  # 나머지 금액 업데이트

        # 각 동전 종류별 개수 저장
        if coin == 500:
            cnt_500 = coin_count
        elif coin == 100:
            cnt_100 = coin_count
        elif coin == 50:
            cnt_50 = coin_count
        elif coin == 10:
            cnt_10 = coin_count

# 결과 출력
print(f"500원: {cnt_500}개, 100원: {cnt_100}개, 50원: {cnt_50}개, 10원: {cnt_10}개, 총 동전 개수: {count}")
# Out:
# 1260
# 500원: 2개, 100원: 2개, 50원: 1개, 10원: 1개, 총 동전 개수: 6

# %%
#@title 실전 문제1. 큰 수의 법칙

# 문제 해설
# 단순하게 푸는 답안 예시

n, m, k = map(int, input().split())
data = list(map(int, input().split()))

data.sort() # 입력받은 수 정렬
first = data[-1] # 가장 큰 수
second = data[-2] # 두번째 큰 수

result = 0

while True :
    for i in range(k): # 가장 큰 수 k번 더하기
        if m == 0: # m이 0 이라면 반복문 탈출
            break
        result += first
        m -= 1 # 더할 때마다 1씩 빼기
    if m == 0:
        break
    result += second
    m -= 1

print(result)
# Out:
# 5 8 3
# 2 4 5 4 6
# 46

# %%
#@title 더 효율적인 해결 방법

# 위 코드에서 m의 크기가 100억 이상처럼 커진다면 시간 초과 판정

# 반복되는 수열에 대해서 파악
# m이 8이고 k가 3이라면 (6+6+6+5)+(6+6+6+5) -> 반복되는 수열의 길이는 (k + 1)

n, m, k = map(int, input().split())
data = list(map(int, input().split()))

data.sort() # 입력받은 수 정렬
first = data[-1] # 가장 큰 수
second = data[-2] # 두번째 큰 수

# 가장 큰 수가 더해지는 횟수 계산
count = int(m / (k + 1)) * k
count += m % (k + 1)

result = 0
result += (count) * first
result += (m - count) * second

print(result)
# Out:
# 5 8 3
# 2 4 5 4 6
# 46

# %%
#@title 실전 문제2. 숫자 카드 게임

# 각 행마다 가장 작은 수 확인하고, 그 수 중에서 가장 큰 수 확인

n, m = map(int, input().split())
li = []
for i in range(n):
    tmp = map(int, input().split())
    min_tmp = min(tmp)
    li.append(min_tmp)

result = max(li)
print(result)
# Out:
# 3 3
# 3 1 2
# 4 1 4
# 2 2 2
# 2

# %%
# 답안 예시1
n, m = map(int, input().split())

result = 0

for i in range(n):
    data = list(map(int, input().split()))
    min_value = min(data)
    # 가장 작은 수 중에서 가장 큰 수 찾기
    result = max(result, min_value)

print(result)
# Out:
# 3 3
# 3 1 2
# 4 1 4
# 2 2 2
# 2

# %%
# 답안 예시2
n, m = map(int, input().split())

result = 0

for i in range(n):
    data = list(map(int, input().split()))
    # 현재 줄에서 가장 작은 수 찾기
    min_value = 10001
    for a in data:
        min_value = min(min_value, a)
    result = max(result, min_value)

print(result)
# Out:
# 3 3
# 3 1 3
# 4 1 4
# 2 2 2
# 2

# %%
#@title 실전 문제3. 1이 될 때까지

# 문제
# 어떠한 수 N이 1이 될 때까지 다음의 두 과정 중 하나를 반복적으로 선택하여 수행.
# 두 번째 연산은 N이 K로나누어떨어질 때만 선택할 수 있다.
# 1. N에서 1을 뺀다
# 2. N을 K로 나눈다
# N이 1이 될 때까지 수행해야 하는 최소 횟수 구하기


# case 분류
# case1: n이 k로 나눠지는 경우 / case2: n이 k로 나눠지지 않는 경우

n, k = map(int, input().split())
count = 0
while True:
    if n % k == 0:
        n = n / k
        count += 1
        if n == 1:
            break
    else:
        n = n - 1
        count += 1
        if n == 1:
            break

print(count)
# Out:
# 17 4
# 3

# %%
# 답안 예시1

n, k = map(int, input().split())
result = 0

# N이 K 이상이라면 K로 계속 나누기
while n >= k:
    # N이 K로 나누어 떨어지지 않는다면 N에서 1씩 빼기
    while n % k != 0:
        n -= 1
        result += 1
    # K로 나누기
    n //= k
    result += 1

# 마지막으로 남은 수에 대하여 1씩 빼기
while n > 1:
    n -= 1
    result += 1

print(result)
# Out:
# 17 4
# 3

# %%
# 답안 예시2

n, k = map(int, input().split())
result = 0

while True:
    # (N == K로 나누어떨어지는 수)가 될 때까지 1씩 빼기
    target = (n // k) * k
    result += (n - target)
    n = target
    # N이 K보다 작을 때(더 이상 나눌 수 없을 때) 반복문 탈출
    if n < k:
        break
    # K로 나누기
    result += 1
    n //= k

# 마지막으로 남은 수에 대하여 1씩 빼기
result += (n - 1)
print(result)
# Out:
# 17 4
# 3
